# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
travel = pd.read_csv('Travel_advisory.csv')

# %%
travel.columns = ['Advisory', 'Level', 'Date updated']

# %%
travel
# Out:
#                                              Advisory  \
# 0                     North Macedonia Travel Advisory
# 1                               Nauru Travel Advisory
# 2                               Palau Travel Advisory
# 3                     Burma (Myanmar) Travel Advisory
# 4                                   Worldwide Caution
# ..                                                ...
# 204                           Georgia Travel Advisory
# 205                             Ghana Travel Advisory
# 206  Democratic Republic of the Congo Travel Advisory
# 207             Republic of the Congo Travel Advisory
# 208                     Guinea-Bissau Travel Advisory
#
#                                    Level      Date updated
# 0                 Level 4: Do Not Travel    April 20, 2021
# 1                 Level 4: Do Not Travel    April 20, 2021
# 2    Level 2: Exercise Increased Caution    April 20, 2021
# 3                 Level 4: Do Not Travel    April 20, 2021
# ...

# %%
index = np.arange(0,209)

# %%
travel['index'] = index

# %%
travel
# Out:
#                                              Advisory  \
# 0                     North Macedonia Travel Advisory
# 1                               Nauru Travel Advisory
# 2                               Palau Travel Advisory
# 3                     Burma (Myanmar) Travel Advisory
# 4                                   Worldwide Caution
# ..                                                ...
# 204                           Georgia Travel Advisory
# 205                             Ghana Travel Advisory
# 206  Democratic Republic of the Congo Travel Advisory
# 207             Republic of the Congo Travel Advisory
# 208                     Guinea-Bissau Travel Advisory
#
#                                    Level      Date updated  index
# 0                 Level 4: Do Not Travel    April 20, 2021      0
# 1                 Level 4: Do Not Travel    April 20, 2021      1
# 2    Level 2: Exercise Increased Caution    April 20, 2021      2
# ...

# %%
# replacing rows in Level column with numbers
travel = travel.replace(to_replace='Level 4: Do Not Travel', value=4)
travel = travel.replace(to_replace='Level 3: Reconsider Travel', value=3)
travel = travel.replace(to_replace='Level 2: Exercise Increased Caution', value=2)
travel = travel.replace(to_replace='Caution', value=1)

# %%
travel
# Out:
#                                              Advisory  Level  \
# 0                     North Macedonia Travel Advisory      4
# 1                               Nauru Travel Advisory      4
# 2                               Palau Travel Advisory      2
# 3                     Burma (Myanmar) Travel Advisory      4
# 4                                   Worldwide Caution      1
# ..                                                ...    ...
# 204                           Georgia Travel Advisory      4
# 205                             Ghana Travel Advisory      3
# 206  Democratic Republic of the Congo Travel Advisory      4
# 207             Republic of the Congo Travel Advisory      4
# 208                     Guinea-Bissau Travel Advisory      4
#
#          Date updated  index
# 0      April 20, 2021      0
# 1      April 20, 2021      1
# 2      April 20, 2021      2
# 3      April 20, 2021      3
# 4    January 15, 2019      4
# ..                ...    ...
# ...

# %%
travel_df = pd.get_dummies(travel,columns=['Level'],prefix=['Level'])

# %%
travel_df

# %%
travel2 = travel.drop(columns =['Date updated'])

# %%
travel2

# %%
advisory = travel2[0:51]
level = travel2[0:51]

# %%
travel2= travel2[0:52]

# %%
travel2

# %%
travel2.plot(kind='scatter',x='Advisory',y='Level',color='red')

# %%
# X = travel['Advisory']
# y = travel['Level']
advisory = []

for i in range(0,209):
    advisory.append(i)
print(advisory)

y = [1,2,3,4]
x = advisory

fig = plt.figure()
ax = plt.subplot(111)
ax.plot(x, y)

# %%
print(x.shape())

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25)

# %%
y_train.values.reshape(-1,1)

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()

# %%
logreg.fit(x_train.values.reshape(-1,1), y_train)

# %%
flight = pd.read_csv('flight_data.csv')

# %%
flight
# Out:
#    Unnamed: 0      type  subType                name  \
# 0           0  location  AIRPORT            HEATHROW
# 1           1  location  AIRPORT             GATWICK
# 2           2  location  AIRPORT               LUTON
# 3           3  location  AIRPORT            STANSTED
# 4           4  location  AIRPORT        CITY AIRPORT
# 5           5  location  AIRPORT          BIRMINGHAM
# 6           6  location  AIRPORT  MANCHESTER AIRPORT
# 7           7  location  AIRPORT         SOUTHAMPTON
# 8           8  location  AIRPORT             BRISTOL
# 9           9  location  AIRPORT       EAST MIDLANDS
#
#                      detailedName timeZoneOffset iataCode  relevance  \
# 0              LONDON/GB:HEATHROW         +01:00      LHR  360.56140
# 1               LONDON/GB:GATWICK         +01:00      LGW   53.99024
# 2                 LONDON/GB:LUTON         +01:00      LTN   32.81459
# 3              LONDON/GB:STANSTED         +01:00      STN   27.45404
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline
from sklearn import datasets

# %%
iris = datasets.load_iris()
x = travel['index']
y = travel['Level']

# %%
plt.figure(figsize=(209, 4))
plt.scatter(x[y == 0][:, 0], x[y == 0][:, 1], color='g', label='0')
plt.scatter(x[y == 1][:, 0], x[y == 1][:, 1], color='y', label='1')
plt.legend();
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-94-7f13c3a4afbe> in <module>
#       1 plt.figure(figsize=(209, 4))
# ----> 2 plt.scatter(x[y == 0][:, 0], x[y == 0][:, 1], color='g', label='0')
#       3 plt.scatter(x[y == 1][:, 0], x[y == 1][:, 1], color='y', label='1')
#       4 plt.legend();
#
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/pandas/core/series.py in __getitem__(self, key)
#     873             return self._get_values(key)
#     874
# --> 875         return self._get_with(key)
#     876
#     877     def _get_with(self, key):
#
# /usr/local/Cellar/jupyterlab/2.2.8/libexec/lib/python3.8/site-packages/pandas/core/series.py in _get_with(self, key)
#     888             )
#     889         elif isinstance(key, tuple):
# --> 890             return self._get_values_tuple(key)
#     891
# ...

# %%
plt.figure(figsize=(4, 4))
plt.scatter(x,y)
plt.legend();
# Out:
# No handles with labels found to put in legend.
